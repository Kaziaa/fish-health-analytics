# %% [markdown]
# ## Day08_Anomaly_Detection_and_Warning_Cases.ipynb

# %% [markdown]
# # Day 8 — Anomaly Detection and Warning Cases
#
# ## Goal
#
# * Identify unusual lice and environmental patterns that may require investigation or early intervention.

# %%
# Load libraries
import pandas as pd
from pathlib import Path

# %%
clean_file = (
    Path.home()
    / "Documents"
    / "Kazi_Academic"
    / "Projects"
    / "Aquaculture"
    / "fish-health-analytics"
    / "data"
    / "processed"
    / "barentswatch_lice_2025_features.csv"
)

df = pd.read_csv(clean_file)
# Out:
# /tmp/ipykernel_166060/106962288.py:13: DtypeWarning: Columns (0: weekly_lice_limit) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(clean_file)
